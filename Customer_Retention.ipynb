# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel("customer_retention_dataset.xlsx")
data.head(5)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
data.sample(10)
# Out:
#     1Gender of respondent 2 How old are you?   \
# 117                Female         31-40 years
# 124                Female         21-30 years
# 263                  Male         41-50 yaers
# 187                  Male  Less than 20 years
# 149                Female         41-50 yaers
# 208                Female         41-50 yaers
# 105                Female         41-50 yaers
# 7                    Male         41-50 yaers
# 214                  Male         31-40 years
# 59                 Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 117                                 Noida
# 124                                 Solan
# 263                                 Delhi
# 187                                 Noida
# 149                            Bangalore
# 208                            Bangalore
# 105                             Ghaziabad
# 7                                   Delhi
# 214                                 Noida
# ...

# %% [markdown]
# # DataAnalysing

# %%
data.shape
# Out:
# (269, 71)

# %%
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
data.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# # DataVisualisation

# %%
sns.countplot(data["1Gender of respondent"])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %%
plt.figure(figsize=[12,5])
sns.countplot(data['3 Which city do you shop online from?'])
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %%
sns.countplot(data['2 How old are you? '])
plt.xticks(rotation=60)
plt.show()

# %%
data['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 250001     9
# 173229     9
# 173212     9
# 560010     8
# 132036     8
# 122018     8
# 560037     8
# 110008     7
# 110011     7
# 201306     7
# 110014     6
# 110018     6
# 201305     5
# 201008     5
# 201009     5
# 201312     5
# 244001     5
# 530068     5
# 122009     4
# 201001     4
# 560003     4
# 201304     4
# 110009     4
# 201303     4
# 560002     4
# 560018     4
# 110042     4
# 110030     4
# 201005     4
# 110039     4
# 560013     3
# 203001     2
# 203202     1
# 560001     1
# 203207     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(data["5 Since How Long You are Shopping Online ?"])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data["6 How many times you have made an online purchase in the past 1 year?"])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %%
data["6 How many times you have made an online purchase in the past 1 year?"].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(data["7 How do you access the internet while shopping on-line?"])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data["8 Which device do you use to access the online shopping?"])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
sns.countplot(data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '])
plt.title("Purchase Decision",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '])
plt.title("Preferred Payment Option",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.title("Information on Similar Products",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['20 Complete information on listed seller and product being offered is important for purchase decision.'])
plt.title("Complete Information",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['25 Convenient Payment methods'])
plt.title("Convenient Payments Method",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['28 Being able to guarantee the privacy of the customer'])
plt.title("Customer Privacy",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['30 Online shopping gives monetary benefit and discounts'])
plt.title("Benefits and Discounts",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['33 Return and replacement policy of the e-tailer is important for purchase decision'])
plt.title("Return and Replacement",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['35 Displaying quality Information on the website improves satisfaction of customers'])
plt.title("Quality Information",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['38 User satisfaction cannot exist without trust'])
plt.title("User Satisfaction",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['39 Offering a wide variety of listed product in several category'])
plt.title("Listed Product_Several Category",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['41 Monetary savings'])
plt.title("Savings",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['43 Shopping on the website gives you the sense of adventure'])
plt.title("Shopping Adventure",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data['47 Getting value for money spent'])
plt.title("Value for Money",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
data["Complete, relevant description information of products"]
# Out:
# 0                                           Snapdeal.com
# 1                    Amazon.in, Flipkart.com, Myntra.com
# 2                       Amazon.in, Paytm.com, Myntra.com
# 3                                Amazon.in, Flipkart.com
# 4      Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#                              ...
# 264                                            Amazon.in
# 265                                         Flipkart.com
# 266                                            Amazon.in
# 267    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                            Amazon.in
# Name: Complete, relevant description information of products, Length: 269, dtype: object

# %%
data["Complete, relevant description information of products"].nunique()
# Out:
# 11

# %%
a = data['Complete, relevant description information of products'].str.get_dummies(',')
a["flipkart.com"] = a[" Flipkart.com"]+a["Flipkart.com"]
a.drop([" Flipkart.com","Flipkart.com"],axis=1,inplace=True)
a["snapdeal.com"] = a[" Snapdeal.com"]+a["Snapdeal.com"]
a.drop([" Snapdeal.com","Snapdeal.com"],axis=1,inplace=True)

sns.swarmplot(x=a.sum(),y=a.sum(),hue=a.columns)
plt.xlabel('Complete, relevant description information of products')
plt.title("products information", fontsize=15)
plt.show()

# %%
Amazon gives the most complete relevant information compare to others.

# %%
a = data['Quickness to complete purchase'].str.get_dummies(',')
a["flipkart.com"] = a[" Flipkart.com"]+a["Flipkart.com"]
a.drop([" Flipkart.com","Flipkart.com"],axis=1,inplace=True)
a["paytm.com"] = a[" Paytm.com"]+a["Paytm.com"]
a.drop([" Paytm.com","Paytm.com"],axis=1,inplace=True)
sns.barplot(x=a.sum(),y=a.sum(),hue=a.columns,dodge=False)
plt.xlabel("Quickness to complete purchase")
plt.title("Quickness to complete purchase",fontsize=15)
plt.show()

# %% [raw]
# Quickness to complete purchase in Amazon is high when compares to others..

# %%
plt.figure(figsize=(8,5))
sns.countplot(y=data['Speedy order delivery '])
plt.show()

# %% [raw]
# 107 respondents believe that amazon.in has the speedy order delivery whereas Flipkart.com, Myntra.com, Snapdeal.com has the least respondents believing in speedy delivery.

# %%
data['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
a = data['Security of customer financial information'].str.get_dummies(',')
a["flipkart.com"] = a[" Flipkart.com"]+a["Flipkart.com"]
a.drop([" Flipkart.com","Flipkart.com"],axis=1,inplace=True)
a["paytm.com"] = a[" Paytm.com"]+a["Paytm.com"]
a.drop([" Paytm.com","Paytm.com"],axis=1,inplace=True)
a["myntra.com"] = a[" Myntra.com"]+a["Myntra.com"]
a.drop([" Myntra.com","Myntra.com"],axis=1,inplace=True)
sns.barplot(x=a.sum(),y=a.sum(),hue=a.columns,dodge=False)
plt.xlabel("Security of customer financial information")
plt.title("Security of financial information", fontsize=15)
plt.show()

# %%
Paytm has the least information in security for customers..

# %%
plt.figure(figsize=(10,5))
a = data['Frequent disruption when moving from one page to another'].str.get_dummies(',')
a["flipkart.com"] = a[" Flipkart.com"]+a["Flipkart.com"]
a.drop([" Flipkart.com","Flipkart.com"],axis=1,inplace=True)
a["snapdeal.com"] = a[" Snapdeal.com"]+a["Snapdeal.com"]
a.drop([" Snapdeal.com","Snapdeal.com"],axis=1,inplace=True)

sns.barplot(x=a.sum(),y=a.sum(),hue=a.columns,dodge=False)
plt.xlabel("Frequent disruption when moving from one page to another")
plt.title("Disruption in website", fontsize=15)
plt.show()

# %% [raw]
# Paytm has the least frequent disruption when moving from one page to another whereas Amazon Snapdeal ha sthe highest in time..

# %%
plt.figure(figsize=(10,5))
a = data['Longer page loading time (promotion, sales period)'].str.get_dummies(',')
a["flipkart.com"] = a[" Flipkart.com"]+a["Flipkart.com"]
a.drop([" Flipkart.com","Flipkart.com"],axis=1,inplace=True)
a["snapdeal.com"] = a[" Snapdeal.com"]+a["Snapdeal.com"]
a.drop([" Snapdeal.com","Snapdeal.com"],axis=1,inplace=True)

sns.barplot(x=a.sum(),y=a.sum(),hue=a.columns,dodge=False)
plt.xlabel("Page loading time")
plt.title("Page loading", fontsize=15)
plt.show()

# %% [raw]
# Paytm carries the most loading time..Whereas Amazon snapdeal flipkart takes next to it.

# %%
plt.figure(figsize=(25,12))
sns.countplot(data["Which of the Indian online retailer would you recommend to a friend?"])
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='count'>

# %% [raw]
# Amazon and flipkart are the most trusted online selling app.

# %%
sns.scatterplot(x=data['46 Shopping on the website helps you fulfill certain roles'],y=data['Wild variety of product on offer'])
# Out:
# <AxesSubplot:xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='Wild variety of product on offer'>

# %% [raw]
# (Hedonic value) and wide variety of product on offer(Utilitarian value) are positively correlated to each other.

# %%
sns.scatterplot(x=data['46 Shopping on the website helps you fulfill certain roles'],y=data['Complete, relevant description information of products'])
# Out:
# <AxesSubplot:xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='Complete, relevant description information of products'>

# %% [raw]
# Hedonic value and Complete relevant description information of products(Utilitarian value) are positively correlated to each other.

# %%
sns.scatterplot(x=data['43 Shopping on the website gives you the sense of adventure'],y=data['Wild variety of product on offer'])
# Out:
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='Wild variety of product on offer'>

# %% [raw]
# Hedonic value and Utilarian value are positiverly corelaterd..
